# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import streamlit as st 
import seaborn as sns
import folium

# %% [markdown]
# ### Importing the Data

# %%
daily = pd.read_csv('dailydata.csv')
station = pd.read_csv('gwl-stations.csv')

# %%
daily.head()
# Out:
#          STATION   MSMT_DATE  WLM_RPE  WLM_RPE_QC  WLM_GSE  WLM_GSE_QC  \
# 0  14N01E35P001M  12/27/2022    48.74           1    46.88           1
# 1  14N01E35P004M  12/27/2022    47.62           1    46.88           1
# 2  16N03W14H004M  12/27/2022    68.21           1    65.70           1
# 3  14N01E35P001M  12/26/2022    48.74           1    46.88           1
# 4  14N01E35P004M  12/26/2022    47.62           1    46.88           1
#
#    RPE_WSE  RPE_WSE_QC  GSE_WSE  GSE_WSE_QC     WSE  WSE_QC
# 0   42.442           2   40.582           2   6.298       2
# 1   20.786           2   20.046           2  26.834       2
# 2   19.735           2   17.225           2  48.475       2
# 3   42.552           2   40.692           2   6.188       2
# 4   20.829           2   20.089           2  26.791       2

# %% [markdown]
# Station = Unique Station identifier for most also well number
#
# MSMT_Data = Date/Time in PST when collected
#
# WLM_RPE = Reference Point Elevation used to collect measurement
#
# WLM_RPE_QC = Quality Code for Measurement
#
# WLM_GSE = Ground surface elevation at well site
#
# WLM_GSE_QC = Quality Code for WLM_GSE measurement
#
# RPE_WSE = Depth to the water surface in feet below the reference point
#
# GSE_WSE = Depth below ground surface or distance from ground surface to
# water surface in feet
#
# GSE_WSE_QC = Quality Code for GSE_WSE MEasurement
#
# WSE = Water Surface Elevation in feet above Mean Sea Level

# %%
daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 12 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   STATION     1048575 non-null  object
#  1   MSMT_DATE   1048575 non-null  object
#  2   WLM_RPE     1042002 non-null  float64
#  3   WLM_RPE_QC  1048575 non-null  int64
#  4   WLM_GSE     1039724 non-null  float64
#  5   WLM_GSE_QC  1048575 non-null  int64
#  6   RPE_WSE     963223 non-null   float64
#  7   RPE_WSE_QC  1048575 non-null  int64
#  8   GSE_WSE     954445 non-null   float64
#  9   GSE_WSE_QC  1048575 non-null  int64
#  10  WSE         956650 non-null   float64
#  11  WSE_QC      1048575 non-null  int64
# dtypes: float64(5), int64(5), object(2)
# memory usage: 96.0+ MB

# %%
daily['STATION'].nunique()
# Out:
# 238

# %%
station.head()
# Out:
#          STATION           SITE_CODE  \
# 0  01N04E36Q001M  378861N1214818W001
# 1  01N04E36Q002M  378849N1214822W001
# 2  01N04E36Q003M  378860N1214819W001
# 3  01N04E36Q004M  378850N1214820W001
# 4  01S04E28F001M  378186N1215443W001
#
#                                               STNAME WELL_NAME   LATITUDE  \
# 0   Middle River Barrier well 2W screen 61-81 ft bgs    MRL-2W  37.886056
# 1   Middle River Barrier well 3W screen 14-34 ft bgs    MRL-3W  37.884861
# 2    Middle River Barrier well 2 screen 10-20 ft bgs    MLNO-2  37.886028
# 3    Middle River Barrier well 1 screen 10-20 ft bgs    MLNO-1  37.885028
# 4  Grant Line Canal Barrier well 2W screen 10-25 ...   GLWL-2W  37.818556
#
#     LONGITUDE LLDATUM      POSACC  ELEV ELEVDATUM          ELEVACC  \
# 0 -121.481833   NAD83  Survey, 1m   6.9       NaN  R.L. AT SURFACE
# 1 -121.482167   NAD83  Survey, 1m  -1.0       NaN  R.L. AT SURFACE
# 2 -121.481917   NAD83  Survey, 1m   8.6       NaN  R.L. AT SURFACE
# 3 -121.482000   NAD83  Survey, 1m  15.9       NaN  R.L. AT SURFACE
# 4 -121.544333   NAD83  Survey, 1m  16.1       NaN  R.L. AT SURFACE
#
#    COUNTY_NAME BASIN_CODE BASIN_NAME  WELL_DEPTH     WELL_USE    WELL_TYPE  \
# 0  San Joaquin   5-022.15      Tracy        81.0  Observation  Single Well
# 1  San Joaquin   5-022.15      Tracy        34.0  Observation  Single Well
# 2  San Joaquin   5-022.15      Tracy        20.0  Observation  Single Well
# 3  San Joaquin   5-022.15      Tracy        20.0  Observation  Single Well
# 4  San Joaquin   5-022.15      Tracy        25.0  Observation  Single Well
#
#   WCR_NO                                                WDL  \
# 0    NaN  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 1    NaN  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 2    NaN  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 3    NaN  https://wdl.water.ca.gov/StationDetails.aspx?S...
# 4    NaN  https://wdl.water.ca.gov/StationDetails.aspx?S...
#
#                                              COMMENT
# 0  01N04E36Q001M is part of a well cluster.  Othe...
# 1  01N04E36Q002M is part of a well cluster.  Othe...
# 2  01N04E36Q003M is part of a well cluster.  Othe...
# 3  01N04E36Q004M is part of a well cluster.  Othe...
# 4  01S04E28F001M is part of a well cluster.  Othe...

# %%
station.nunique()
# Out:
# STATION        551
# SITE_CODE      540
# STNAME         551
# WELL_NAME      514
# LATITUDE       304
# LONGITUDE      304
# LLDATUM          2
# POSACC           3
# ELEV           325
# ELEVDATUM        1
# ELEVACC          7
# COUNTY_NAME     15
# BASIN_CODE      26
# BASIN_NAME      26
# WELL_DEPTH     317
# WELL_USE         7
# WELL_TYPE        3
# WCR_NO         282
# WDL            551
# COMMENT        196
# dtype: int64

# %% [markdown]
# There are more stations in this dataset than there are stations in the main dataset, we will need to extract the matching ones.

# %% [markdown]
# ### Finding Common Stations from Secondary Data Set

# %%
Uniq_Stats = list(dict.fromkeys(daily['STATION']))

# %%
station_short = station[station['STATION'].isin(Uniq_Stats)]
station_short.nunique()
# Out:
# STATION        238
# SITE_CODE      229
# STNAME         238
# WELL_NAME      238
# LATITUDE       124
# LONGITUDE      124
# LLDATUM          2
# POSACC           3
# ELEV           125
# ELEVDATUM        1
# ELEVACC          6
# COUNTY_NAME     10
# BASIN_CODE      13
# BASIN_NAME      13
# WELL_DEPTH     163
# WELL_USE         3
# WELL_TYPE        2
# WCR_NO          95
# WDL            238
# COMMENT        174
# dtype: int64

# %%
plt.figure(figsize=(8, 10))
sns.heatmap(station_short.isnull(), cbar=False, yticklabels=False, cmap='viridis')
plt.title('Missing Values in Station Dataset')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 10))
sns.heatmap(daily.isnull(), cbar=False, yticklabels=False, cmap='viridis')
plt.title('Missing Values in Daily Dataset')
plt.tight_layout()
plt.show()

# %%
Merged = pd.merge(daily, station, on = 'STATION', how = 'inner')

# %%
Merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 31 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   STATION      1048575 non-null  object
#  1   MSMT_DATE    1048575 non-null  object
#  2   WLM_RPE      1042002 non-null  float64
#  3   WLM_RPE_QC   1048575 non-null  int64
#  4   WLM_GSE      1039724 non-null  float64
#  5   WLM_GSE_QC   1048575 non-null  int64
#  6   RPE_WSE      963223 non-null   float64
#  7   RPE_WSE_QC   1048575 non-null  int64
#  8   GSE_WSE      954445 non-null   float64
#  9   GSE_WSE_QC   1048575 non-null  int64
#  10  WSE          956650 non-null   float64
#  11  WSE_QC       1048575 non-null  int64
#  12  SITE_CODE    1041906 non-null  object
#  13  STNAME       1048575 non-null  object
#  14  WELL_NAME    1048575 non-null  object
#  15  LATITUDE     1048575 non-null  float64
#  16  LONGITUDE    1048575 non-null  float64
#  17  LLDATUM      1048575 non-null  object
#  18  POSACC       1048575 non-null  object
#  19  ELEV         1048575 non-null  float64
#  20  ELEVDATUM    33249 non-null    object
#  21  ELEVACC      1048575 non-null  object
#  22  COUNTY_NAME  1048575 non-null  object
#  23  BASIN_CODE   1041906 non-null  object
#  24  BASIN_NAME   1041906 non-null  object
#  25  WELL_DEPTH   1040126 non-null  float64
#  26  WELL_USE     1041906 non-null  object
#  27  WELL_TYPE    1041906 non-null  object
#  28  WCR_NO       686812 non-null   object
#  29  WDL          1048575 non-null  object
#  30  COMMENT      789257 non-null   object
# dtypes: float64(9), int64(5), object(17)
# memory usage: 248.0+ MB

# %%
Key_data = Merged[['STATION','MSMT_DATE','WLM_RPE','WLM_GSE','RPE_WSE', 'GSE_WSE','WSE','LATITUDE','LONGITUDE']]

# %%
Key_data.head()
# Out:
#          STATION   MSMT_DATE  WLM_RPE  WLM_GSE  RPE_WSE  GSE_WSE     WSE  \
# 0  14N01E35P001M  12/27/2022    48.74    46.88   42.442   40.582   6.298
# 1  14N01E35P004M  12/27/2022    47.62    46.88   20.786   20.046  26.834
# 2  16N03W14H004M  12/27/2022    68.21    65.70   19.735   17.225  48.475
# 3  14N01E35P001M  12/26/2022    48.74    46.88   42.552   40.692   6.188
# 4  14N01E35P004M  12/26/2022    47.62    46.88   20.829   20.089  26.791
#
#     LATITUDE   LONGITUDE
# 0  39.012435 -121.829041
# 1  39.012435 -121.829041
# 2  39.241473 -122.153517
# 3  39.012435 -121.829041
# 4  39.012435 -121.829041

# %%
plt.figure(figsize=(8, 10))
sns.heatmap(Key_data.isnull(), cbar=False, yticklabels=False, cmap='viridis')
plt.title('Missing Values in Key_data Dataset')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Sorting by Station

# %%
Sort_KD = Key_data.sort_values(by = ['STATION', 'MSMT_DATE'], ascending = True)

# %% [markdown]
# There are multiple stations per coordinate.

# %%
plt.figure(figsize=(8, 10))
sns.heatmap(Sort_KD.isnull(), cbar=False, yticklabels=False, cmap='viridis')
plt.title('Missing Values in Sort_KD Dataset')
plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the heatmap shown above where all the data is sorted by station and then date, I believe that the data shown is MCAR.
# For groundwater data there should not be drastic shifts on a short time scale, thus I believe it would be best to use a simplified version of K-nearest neighbors to base each NaN value on the nearest date before and after. I am only applying this for RPE_WSE, GSE_WSE, and WSE as these are values that change with time. The other two columns with missing data are the reference points and surface elevation which are mostly static.

# %%
Sort_KD.describe()
# Out:
#             WLM_RPE       WLM_GSE        RPE_WSE        GSE_WSE  \
# count  1.042002e+06  1.039724e+06  963223.000000  954445.000000
# mean   4.991109e+01  4.812979e+01      21.899209      20.253326
# std    4.908236e+01  4.899384e+01      19.311263      19.477138
# min   -5.700000e-01 -3.170000e+00     -12.492000     -15.292000
# 25%    2.645000e+01  2.500000e+01       9.922000       8.360000
# 50%    3.669200e+01  3.554600e+01      16.798000      15.187000
# 75%    6.821000e+01  6.570000e+01      27.683000      26.195000
# max    5.226500e+02  5.200000e+02     187.804000     186.534000
#
#                  WSE      LATITUDE     LONGITUDE
# count  956650.000000  1.048575e+06  1.048575e+06
# mean       27.523056  3.883887e+01 -1.217297e+02
# std        49.853360  4.514712e-01  2.490049e-01
# min      -170.798000  3.780969e+01 -1.233685e+02
# 25%         2.888000  3.864643e+01 -1.218279e+02
# 50%        19.063000  3.891160e+01 -1.216675e+02
# 75%        48.565000  3.917588e+01 -1.215436e+02
# max       514.804000  3.949270e+01 -1.211169e+02

# %%
KD_nan = Sort_KD.isna().sum()
print(KD_nan)
# Out:
# STATION          0
# MSMT_DATE        0
# WLM_RPE       6573
# WLM_GSE       8851
# RPE_WSE      85352
# GSE_WSE      94130
# WSE          91925
# LATITUDE         0
# LONGITUDE        0
# dtype: int64

# %% [markdown]
# ### Interpolation/Imputation
# The following interpolation was done with the help of Google AI studio version 2.5, 10/15/25

# %%
Sort_KD['MSMT_DATE'].head()
# Out:
# 959070    1/1/2006
# 932095    1/1/2007
# 895960    1/1/2008
# 852734    1/1/2009
# 808798    1/1/2010
# Name: MSMT_DATE, dtype: object

# %% [markdown]
# I realized the datetime data is still a string

# %%
Sort_KD['MSMT_DATE'] = pd.to_datetime(Sort_KD['MSMT_DATE'])

# %%
Sort_KD['MSMT_DATE'].head()
# Out:
# 959070   2006-01-01
# 932095   2007-01-01
# 895960   2008-01-01
# 852734   2009-01-01
# 808798   2010-01-01
# Name: MSMT_DATE, dtype: datetime64[ns]

# %%
Sort_KD = Sort_KD.sort_values(by = ['STATION', 'MSMT_DATE'], ascending = True)

# %%
Sort_KD.head()
# Out:
#               STATION  MSMT_DATE  WLM_RPE  WLM_GSE  RPE_WSE  GSE_WSE    WSE  \
# 973704  01N04E36Q001M 2005-04-30      9.1      6.9   17.354   15.154 -8.254
# 973650  01N04E36Q001M 2005-05-01      9.1      6.9   17.348   15.148 -8.248
# 973596  01N04E36Q001M 2005-05-02      9.1      6.9   17.343   15.143 -8.243
# 973542  01N04E36Q001M 2005-05-03      9.1      6.9   17.358   15.158 -8.258
# 973488  01N04E36Q001M 2005-05-04      9.1      6.9   17.354   15.154 -8.254
#
#          LATITUDE   LONGITUDE
# 973704  37.886056 -121.481833
# 973650  37.886056 -121.481833
# 973596  37.886056 -121.481833
# 973542  37.886056 -121.481833
# 973488  37.886056 -121.481833

# %%
Sort_KD = Sort_KD.set_index('MSMT_DATE')

# Group by 'STATION', select the 'value' column, and apply interpolation.
# The lambda function operates on each group (each station's data) separately.
Sort_KD['RPE_WSE'] = Sort_KD.groupby('STATION')['RPE_WSE'].transform(
    lambda group: group.interpolate(method='time').ffill().bfill())
Sort_KD['GSE_WSE'] = Sort_KD.groupby('STATION')['GSE_WSE'].transform(
    lambda group: group.interpolate(method='time').ffill().bfill())
Sort_KD['WSE'] = Sort_KD.groupby('STATION')['WSE'].transform(
    lambda group: group.interpolate(method='time').ffill().bfill())

# Reset the index to bring 'MSMT_DATE' back as a regular column
Sort_KD = Sort_KD.reset_index()

# %%
plt.figure(figsize=(8, 10))
sns.heatmap(Sort_KD.isnull(), cbar=False, yticklabels=False, cmap='viridis')
plt.title('Missing Values in Sort_KD Dataset')
plt.tight_layout()
plt.show()

# %%
KD_nan = Sort_KD.isna().sum()
print(KD_nan)
# Out:
# MSMT_DATE       0
# STATION         0
# WLM_RPE      6573
# WLM_GSE      8851
# RPE_WSE         0
# GSE_WSE      8851
# WSE          6573
# LATITUDE        0
# LONGITUDE       0
# dtype: int64

# %% [markdown]
# As shown below, 9 stations are contributing all of the missingness. If there is still NaN based on the code above that means that there is no data whatsoever to interpolate so I will cut the stations listed below.

# %%
droplist = (Sort_KD['STATION'][Sort_KD['GSE_WSE'].isnull()].unique())
print(droplist)
# Out:
# ['03N04E11L001M' '04N04E10Q001M' '04N04E10Q002M' '04N04E13A001M'
#  '04N04E13A002M' '04N04E34N001M' '04N04E34N002M' '14N02W22A002M'
#  '18N01E21L001M']

# %%
Data_Final = Sort_KD[~Sort_KD['STATION'].isin(droplist)]

# %%
plt.figure(figsize=(8, 10))
sns.heatmap(Data_Final.isnull(), cbar=False, yticklabels=False, cmap='viridis')
plt.title('Missing Values in Sort_KD Dataset')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Encoding Station Numbers
# I will keep the station code, however it'll be far easier to search by station 1, station 2, station 3, etc

# %%
Data_Final['Station_Num'] = Data_Final.groupby('STATION').ngroup()
# Out:
# C:\Users\Groul\AppData\Local\Temp\ipykernel_34796\132928052.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Data_Final['Station_Num'] = Data_Final.groupby('STATION').ngroup().copy()

# %%
Data_Final.head()
# Out:
#    MSMT_DATE        STATION  WLM_RPE  WLM_GSE  RPE_WSE  GSE_WSE    WSE  \
# 0 2005-04-30  01N04E36Q001M      9.1      6.9   17.354   15.154 -8.254
# 1 2005-05-01  01N04E36Q001M      9.1      6.9   17.348   15.148 -8.248
# 2 2005-05-02  01N04E36Q001M      9.1      6.9   17.343   15.143 -8.243
# 3 2005-05-03  01N04E36Q001M      9.1      6.9   17.358   15.158 -8.258
# 4 2005-05-04  01N04E36Q001M      9.1      6.9   17.354   15.154 -8.254
#
#     LATITUDE   LONGITUDE  Station_Num
# 0  37.886056 -121.481833            0
# 1  37.886056 -121.481833            0
# 2  37.886056 -121.481833            0
# 3  37.886056 -121.481833            0
# 4  37.886056 -121.481833            0

# %%
print(Data_Final['Station_Num'].max())
# Out:
# 228

# %% [markdown]
# ### Practice Producing Plots by Station
# I will come back and refine this later, I just wanted to have a method of seperating the stations for various graphs I will develop. I plan to have users either search by coordinate and have the nearest well pop up or click on a map.

# %%
def Scatter_stat(station = 0, parameter = 'GSE_WSE'):
    data = Data_Final[Data_Final['Station_Num'] == station]
    fig = plt.figure(figsize = (18,10))
    plot = plt.plot(data['MSMT_DATE'],data[parameter])
    plt.tight_layout()
    return fig

# %%
Example_1 = Scatter_stat(182)

# %% [markdown]
# ### Beginning to play with the map

# %%
#Google AI Studio version 2.5 10/15/25
Coords = Data_Final.groupby('Station_Num')[['LATITUDE', 'LONGITUDE']].first()

print(Coords)
# Out:
#               LATITUDE   LONGITUDE
# Station_Num
# 0            37.886056 -121.481833
# 1            37.884861 -121.482167
# 2            37.886028 -121.481917
# 3            37.885028 -121.482000
# 4            37.818556 -121.544333
# ...                ...         ...
# 224          39.420773 -122.134145
# 225          39.463547 -121.827619
# 226          39.463439 -121.827750
# 227          39.463439 -121.827750
# 228          39.492702 -121.964808
#
# [229 rows x 2 columns]

# %%
california = folium.Map(max_bounds = True, location=[36.7783, -119.4179], zoom_start=6, min_lat=36,max_lat=40,min_lon=-124,max_lon=-119)
for i in Coords.index:
     folium.Marker(
        location= [Coords.iloc[i,0],Coords.iloc[i,1]],
        tooltip= 'Click Me',  # Optional: tooltip on hover
        popup = f'Station {i}'
    ).add_to(california)
display(california)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ddb7cf02af556d1789c3475d0964424f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ddb7cf02af556d1789c3475d0964424f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ddb7cf02af556d1789c3475d0964424f = L.map(
#                 &quot;map_ddb7cf02af556d1789c3475d0964424f&quot;,
#                 {
#                     center: [36.7783, -119.4179],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: [
# [
# 36,
# -124,
# ],
# [
# 40,
# -119,
# ],
# ],
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_592d27aa525c6a11837a67569ccc4fef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_592d27aa525c6a11837a67569ccc4fef.addTo(map_ddb7cf02af556d1789c3475d0964424f);
#
#
#             var marker_25b4b7c548bbe0b645480e39ae023a45 = L.marker(
#                 [37.88605556, -121.48183333],
#                 {
# }
#             ).addTo(map_ddb7cf02af556d1789c3475d0964424f);
#
#
#         var popup_7dd0605e1095e6074d1a2ff6adf4a3ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d152bb5727f88ba18286fd4ef5b3b66b = $(`&lt;div id=&quot;html_d152bb5727f88ba18286fd4ef5b3b66b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station 0&lt;/div&gt;`)[0];
#                 popup_7dd0605e1095e6074d1a2ff6adf4a3ec.setContent(html_d152bb5727f88ba18286fd4ef5b3b66b);
#
#
#
#         marker_25b4b7c548bbe0b645480e39ae023a45.bindPopup(popup_7dd0605e1095e6074d1a2ff6adf4a3ec)
#         ;
#
#
#
#
#             marker_25b4b7c548bbe0b645480e39ae023a45.bindTooltip(
#                 `&lt;div&gt;
#                      Click Me
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_a8beae10dd28e1a01cd295a6b0cb0486 = L.marker(
#                 [37.88486111, -121.48216667],
#                 {
# }
#             ).addTo(map_ddb7cf02af556d1789c3475d0964424f);
#
#
#         var popup_e10489847a95cc0b0035cdbea09ef77c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b101a9b92f3e55e79b256158255a617 = $(`&lt;div id=&quot;html_2b101a9b92f3e55e79b256158255a617&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station 1&lt;/div&gt;`)[0];
#                 popup_e10489847a95cc0b0035cdbea09ef77c.setContent(html_2b101a9b92f3e55e79b256158255a617);
#
#
#
#         marker_a8beae10dd28e1a01cd295a6b0cb0486.bindPopup(popup_e10489847a95cc0b0035cdbea09ef77c)
#         ;
#
#
#
#
#             marker_a8beae10dd28e1a01cd295a6b0cb0486.bindTooltip(
#                 `&lt;div&gt;
#                      Click Me
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_04aa42bbbbcf38b91af37e65d7511774 = L.marker(
#                 [37.88602778, -121.48191667],
#                 {
# }
#             ).addTo(map_ddb7cf02af556d1789c3475d0964424f);
#
#
#         var popup_23aac064ef570ba7b3c94bdca204f78f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b434f2710cedeb58345ca24806d86608 = $(`&lt;div id=&quot;html_b434f2710cedeb58345ca24806d86608&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station 2&lt;/div&gt;`)[0];
#                 popup_23aac064ef570ba7b3c94bdca204f78f.setContent(html_b434f2710cedeb58345ca24806d86608);
#
#
#
#         marker_04aa42bbbbcf38b91af37e65d7511774.bindPopup(popup_23aac064ef570ba7b3c94bdca204f78f)
#         ;
#
#
#
#
#             marker_04aa42bbbbcf38b91af37e65d7511774.bindTooltip(
#                 `&lt;div&gt;
#                      Click Me
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_c47f7435ca556c9f1c0034cea4eb73b4 = L.marker(
#                 [37.88502778, -121.482],
#                 {
# }
#             ).addTo(map_ddb7cf02af556d1789c3475d0964424f);
#
#
#         var popup_5fc548107a31d3afbfad9d6554001cc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_155254ef55132b7e05741bb40652df1e = $(`&lt;div id=&quot;html_155254ef55132b7e05741bb40652df1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station 3&lt;/div&gt;`)[0];
#                 popup_5fc548107a31d3afbfad9d6554001cc2.setContent(html_155254ef55132b7e05741bb40652df1e);
#
#
#
#         marker_c47f7435ca556c9f1c0034cea4eb73b4.bindPopup(popup_5fc548107a31d3afbfad9d6554001cc2)
#         ;
#
#
#
#
#             marker_c47f7435ca556c9f1c0034cea4eb73b4.bindTooltip(
#                 `&lt;div&gt;
#                      Click Me
#                  &lt;/div&gt;`,
